# %% [markdown]
# # v08-tuning-and-scientific-benchmarking
# Paired IRkernel lesson for sciModelFlowR 0.9.0. Execute locally during certification.

# %%
library(sciModelFlowR)
smf_doctor()

# %%
stopifnot(as.character(packageVersion("sciModelFlowR")) == "1.0.2")
